# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
prices = pd.read_csv('data/tariff/network_prices_1h.csv',
                     index_col=0,
                     parse_dates=True,
                     comment='#')
prices
# Out:
#                      pun
# Datetime UTC
# 2023-01-01 00:00:00 0.02
# 2023-01-01 01:00:00 0.02
# 2023-01-01 02:00:00 0.02
# 2023-01-01 03:00:00 0.02
# 2023-01-01 04:00:00 0.02
# ...                  ...
# 2023-12-31 19:00:00 0.02
# 2023-12-31 20:00:00 0.02
# 2023-12-31 21:00:00 0.02
# 2023-12-31 22:00:00 0.01
# 2023-12-31 23:00:00 0.01
#
# [8760 rows x 1 columns]

# %%
pd.options.plotting.backend = 'matplotlib'

# %%
d = prices.pun.values
T = 168
d = d[:int(len(d)/T)*T].reshape(-1,T)

plt.plot(d.T,alpha=0.1);
